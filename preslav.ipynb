# %%
from yaml_query import *
qd = query_data("cond_data/dataframe_conditioned.csv")

# %%
pd = qd.query_search("query_4.yaml")

# %%
pd[1][0]
# Out:
#        Unnamed: 0 Plane       VG       VD  Location Criteria  Height  Width  \
# 16858       16858    XY  0.70625  0.61250         6  abs_pot       3      3
# 16860       16860    XY  0.80000  0.42500         5  abs_pot       3      3
# 16894       16894    XY  0.05000  0.42500        22  abs_pot       3      3
# 16898       16898    XY  0.42500  0.42500        16  abs_pot       3      3
# 16913       16913    XY  0.42500  0.33125        25  abs_pot       3      3
# ...           ...   ...      ...      ...       ...      ...     ...    ...
# 29988       29988    XY  0.80000  0.33125        10  abs_pot       3      3
# 29994       29994    XY  0.33125  0.70625         5  abs_pot       3      3
# 30014       30014    XY  0.14375  0.61250         1  abs_pot       3      3
# 30034       30034    XY  0.61250  0.70625         3  abs_pot       3      3
# 30046       30046    XY  0.23750  0.05000        21  abs_pot       3      3
#
# ...
